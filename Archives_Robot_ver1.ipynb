# %% [markdown]
# <a href="https://colab.research.google.com/github/kirokrobot/Smart-Archives/blob/master/Archives_Robot_ver1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"hello world"
# Out:
# 'hello world'
